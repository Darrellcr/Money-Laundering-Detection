# %%
import math
from pathlib import Path

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset_path = Path("../dataset")
accounts_path = dataset_path / "HI-Small_accounts.csv"
sample_transactions_path = dataset_path / "transactions_test_sample.csv"
all_transactions_path = dataset_path / "HI-Small_Trans.csv"
print(f"{accounts_path=}")
print(f"{sample_transactions_path=}")
print(f"{all_transactions_path=}")
# Out:
# accounts_path=PosixPath('../dataset/HI-Small_accounts.csv')
# sample_transactions_path=PosixPath('../dataset/transactions_test_sample.csv')
# all_transactions_path=PosixPath('../dataset/HI-Small_Trans.csv')

# %%
sample_transactions = pd.read_csv(sample_transactions_path)
all_transactions = pd.read_csv(all_transactions_path)
accounts = pd.read_csv(accounts_path)

# %%
sample_transactions.head(20)
# Out:
#            Timestamp  From Bank  From Account  To Bank To Account  \
# 0   2022/09/01 00:06      21174     800737690       12  80011F990
# 1   2022/09/01 04:33      21174     800737690       20  80020C5B0
# 2   2022/09/01 09:14      21174     800737690       20  80006A5E0
# 3   2022/09/01 09:56      21174     800737690      220  8007A5B70
# 4   2022/09/01 11:28      21174     800737690     1244  80093C0D0
# 5   2022/09/01 13:13      21174     800737690      513  80078E200
# 6   2022/09/01 14:11      21174     800737690       20  80066B990
# 7   2022/09/02 15:40      21174     800737690      410  8002CC310
# 8   2022/09/02 21:23      21174     800737690     1292  8004030A0
# 9   2022/09/02 23:10      21174     800737690     1601  800578800
# 10  2022/09/03 09:29      21174     800737690        1  800AAF0B0
# 11  2022/09/03 14:22      21174     800737690     1420  8006FB970
# 12  2022/09/04 07:35      21174     800737690       10  800449990
# 13  2022/09/04 09:10      21174     800737690    11852  800AEBA90
# 14  2022/09/04 12:03      21174     800737690       10  800692550
# 15  2022/09/04 15:48      21174     800737690    11056  8007486D0
#
#     Amount Received Receiving Currency  Amount Paid Payment Currency  \
# 0           2848.96               Euro      2848.96             Euro
# 1           8630.40               Euro      8630.40             Euro
# 2          35642.49               Yuan     35642.49             Yuan
# 3        5738987.96          US Dollar   5738987.96        US Dollar
# 4           7254.53          US Dollar      7254.53        US Dollar
# 5           6990.87          US Dollar      6990.87        US Dollar
# 6          12536.92               Euro     12536.92             Euro
# 7           3511.82               Euro      3511.82             Euro
# 8          16135.09          US Dollar     16135.09        US Dollar
# 9          12183.28          US Dollar     12183.28        US Dollar
# 10         15197.45          US Dollar     15197.45        US Dollar
# 11          4717.76          US Dollar      4717.76        US Dollar
# 12         19332.59          US Dollar     19332.59        US Dollar
# 13           300.93               Euro       300.93             Euro
# 14          2724.99          US Dollar      2724.99        US Dollar
# 15         15224.53               Euro     15224.53             Euro
#
#    Payment Format  Is Laundering
# 0             ACH              1
# 1             ACH              1
# 2             ACH              1
# 3             ACH              1
# 4             ACH              1
# 5             ACH              1
# 6             ACH              1
# 7             ACH              1
# 8             ACH              1
# 9             ACH              1
# 10            ACH              1
# 11            ACH              1
# 12            ACH              1
# 13            ACH              1
# 14            ACH              1
# 15            ACH              1

# %%
all_transactions.columns
# Out:
# Index(['Timestamp', 'From Bank', 'Account', 'To Bank', 'Account.1',
#        'Amount Received', 'Receiving Currency', 'Amount Paid',
#        'Payment Currency', 'Payment Format', 'Is Laundering'],
#       dtype='str')

# %%
sample_transactions
# Out:
#            Timestamp  From Bank  From Account  To Bank To Account  \
# 0   2022/09/01 00:06      21174     800737690       12  80011F990
# 1   2022/09/01 04:33      21174     800737690       20  80020C5B0
# 2   2022/09/01 09:14      21174     800737690       20  80006A5E0
# 3   2022/09/01 09:56      21174     800737690      220  8007A5B70
# 4   2022/09/01 11:28      21174     800737690     1244  80093C0D0
# 5   2022/09/01 13:13      21174     800737690      513  80078E200
# 6   2022/09/01 14:11      21174     800737690       20  80066B990
# 7   2022/09/02 15:40      21174     800737690      410  8002CC310
# 8   2022/09/02 21:23      21174     800737690     1292  8004030A0
# 9   2022/09/02 23:10      21174     800737690     1601  800578800
# 10  2022/09/03 09:29      21174     800737690        1  800AAF0B0
# 11  2022/09/03 14:22      21174     800737690     1420  8006FB970
# 12  2022/09/04 07:35      21174     800737690       10  800449990
# 13  2022/09/04 09:10      21174     800737690    11852  800AEBA90
# 14  2022/09/04 12:03      21174     800737690       10  800692550
# 15  2022/09/04 15:48      21174     800737690    11056  8007486D0
#
#     Amount Received Receiving Currency  Amount Paid Payment Currency  \
# 0           2848.96               Euro      2848.96             Euro
# 1           8630.40               Euro      8630.40             Euro
# 2          35642.49               Yuan     35642.49             Yuan
# 3        5738987.96          US Dollar   5738987.96        US Dollar
# 4           7254.53          US Dollar      7254.53        US Dollar
# 5           6990.87          US Dollar      6990.87        US Dollar
# 6          12536.92               Euro     12536.92             Euro
# 7           3511.82               Euro      3511.82             Euro
# 8          16135.09          US Dollar     16135.09        US Dollar
# 9          12183.28          US Dollar     12183.28        US Dollar
# 10         15197.45          US Dollar     15197.45        US Dollar
# 11          4717.76          US Dollar      4717.76        US Dollar
# 12         19332.59          US Dollar     19332.59        US Dollar
# 13           300.93               Euro       300.93             Euro
# 14          2724.99          US Dollar      2724.99        US Dollar
# 15         15224.53               Euro     15224.53             Euro
#
#    Payment Format  Is Laundering
# 0             ACH              1
# 1             ACH              1
# 2             ACH              1
# 3             ACH              1
# 4             ACH              1
# 5             ACH              1
# 6             ACH              1
# 7             ACH              1
# 8             ACH              1
# 9             ACH              1
# 10            ACH              1
# 11            ACH              1
# 12            ACH              1
# 13            ACH              1
# 14            ACH              1
# 15            ACH              1

# %%
df1 = sample_transactions[['From Bank', 'From Account']].drop_duplicates()
df2 = sample_transactions[['To Bank', 'To Account']].drop_duplicates()
df1.columns = ['Bank ID', 'Account Number']
df2.columns = ['Bank ID', 'Account Number']
sample_accounts= pd.concat([df1, df2], ignore_index=True).drop_duplicates()
sample_accounts['Bank ID'] = sample_accounts['Bank ID'].astype(int)
sample_accounts['Account Number'] = sample_accounts['Account Number'].astype(str)
sample_accounts.head(20)
# Out:
#     Bank ID Account Number
# 0     21174      800737690
# 1        12      80011F990
# 2        20      80020C5B0
# 3        20      80006A5E0
# 4       220      8007A5B70
# 5      1244      80093C0D0
# 6       513      80078E200
# 7        20      80066B990
# 8       410      8002CC310
# 9      1292      8004030A0
# 10     1601      800578800
# 11        1      800AAF0B0
# 12     1420      8006FB970
# 13       10      800449990
# 14    11852      800AEBA90
# 15       10      800692550
# 16    11056      8007486D0

# %%
sample_accounts = accounts.merge(sample_accounts, on=["Bank ID", "Account Number"], how="inner")
sample_accounts.head(20)
# Out:
#                        Bank Name  Bank ID Account Number  Entity ID  \
# 0                  China Bank #6       20      80020C5B0  800912E30
# 1              Germany Bank #214    11056      8007486D0  8008D3CD0
# 2       National Bank of Laramie       10      800692550  800E8B090
# 3            Netherlands Bank #4    11852      800AEBA90  8006D9F10
# 4            Bank of Arkadelphia     1244      80093C0D0  800B07FB0
# 5   National Bank of New Orleans      513      80078E200  800C91940
# 6      National Bank of the East       12      80011F990  800621E60
# 7               Bank of the West    21174      800737690  800D7B030
# 8    National Bank of Pittsburgh      220      8007A5B70  800EAAFE0
# 9        Savings Bank of Seattle     1292      8004030A0  80008D3C0
# 10            Arbor Savings Bank        1      800AAF0B0  800A88540
# 11             Germany Bank #126      410      8002CC310  800636C60
# 12      National Bank of Laramie       10      800449990  80004B6A0
# 13         Acme Cooperative Bank     1601      800578800  8000C3DE0
# 14                Golden Bancorp     1420      8006FB970  800FBCC20
# 15                 China Bank #6       20      80006A5E0  80099E290
# 16                 China Bank #6       20      80066B990  8006053B0
#
#                    Entity Name
# 0   Sole Proprietorship #22187
# 1    Sole Proprietorship #5797
# 2     Sole Proprietorship #982
# 3   Sole Proprietorship #21628
# 4            Corporation #3438
# 5            Partnership #1318
# 6           Corporation #20103
# 7   Sole Proprietorship #18950
# 8   Sole Proprietorship #17263
# 9             Partnership #538
# 10  Sole Proprietorship #14551
# 11          Corporation #20201
# 12    Sole Proprietorship #555
# 13    Sole Proprietorship #792
# 14           Partnership #1223
# 15          Corporation #21780
# 16          Partnership #24807

# %%
sample_accounts.to_csv("../dataset/accounts_test_sample.csv", index=False)

# %%
sample_transactions['From Bank'] = sample_transactions['From Bank'].astype(int)
sample_transactions['To Bank'] = sample_transactions['To Bank'].astype(int)

# %%
sample_transactions.to_csv("../dataset/transactions_test_sample.csv", index=False)
